# %%
#mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pathlib
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.preprocessing.image import load_img

# %% [markdown]
# **Data Reading/Data Understanding**

# %%
# Path for train and test images
data_dir_train = pathlib.Path("/content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
data_dir_test = pathlib.Path("/content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Test/")

# %%
# Count the number of image in Train and Test directory
# Using the glob to retrieve files/pathnames matching a specified pattern.

#Train Image count
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
#Test Image count
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2247
# 118

# %% [markdown]
# **Dataset creation**

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
# train dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=batch_size,
                                                               image_size=(img_height,img_width), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)

#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes),
#representing a one-hot encoding of the class index.
# Out:
# Found 11247 files belonging to 9 classes.
# Using 8998 files for training.

# %%
# validation dataset
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=batch_size,
                                                            image_size=(img_height,img_width), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 11247 files belonging to 9 classes.
# Using 2249 files for validation.

# %% [markdown]
# **Dataset visualisation**

# %%
#Visualization
image_dataset = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),
                                                                    label_mode='categorical',seed=123)

#classes of Skin Cancer
class_names = image_dataset.class_names

#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))

#Visualize image
plt.figure(figsize=(15,15))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")
# Out:
# Found 11247 files belonging to 9 classes.

# %%
def class_distribution_count(directory):

    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))

    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]

    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'Image Count'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  Image Count
# 0           actinic keratosis          114
# 1                    melanoma          438
# 2        basal cell carcinoma          376
# 3              dermatofibroma           95
# 4        seborrheic keratosis           77
# 5  pigmented benign keratosis          462
# 6                       nevus          365
# 7     squamous cell carcinoma          181
# 8             vascular lesion          139

# %%
#Visualize the Number of image in each class.
plt.figure(figsize=(6, 6))
sns.barplot(x="Image Count", y="Class", data=df, label="Class")
# Out:
# <Axes: xlabel='Image Count', ylabel='Class'>

# %%
#tf.data.experimental.AUTOTUNE defines appropriate number of processes that are free for working.
#`Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#`Dataset.prefetch()` overlaps data preprocessing and model execution while training.

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Model Building & training**

# %%
def BuildModel():
  #CNN Model Architecture
  #Sequential allows you to create models layer-by-layer
  model = Sequential()

  model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

  #First Convulation layer
  model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
  model.add(layers.MaxPool2D(pool_size=(2,2)))

  #Second Convulation Layer
  model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
  model.add(layers.MaxPool2D(pool_size=(2,2)))

  #Third Convulation Layer
  model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
  model.add(layers.MaxPool2D(pool_size=(2,2)))

  #Dropout layer with 50% Fraction of the input units to drop.
  model.add(layers.Dropout(0.5))

  #Flatten Layer
  ##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
  model.add(layers.Flatten())

  #Dense Layer
  model.add(layers.Dense(128,activation='relu'))

  #Dropout layer with 25% Fraction of the input units to drop.
  model.add(layers.Dropout(0.25))

  #Dense Layer with softmax activation function.
  #Softmax is an activation function that scales numbers/logits into probabilities.
  model.add(layers.Dense(len(class_names),activation='softmax'))

  model.summary()
  return model

model = BuildModel()
model
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 89, 89, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  dropout (Dropout)           (None, 20, 20, 128)       0
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6648137 (25.36 MB)
# Trainable params: 6648137 (25.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# vizualizing the model
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
  #Compile the Model
  #Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
  #categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

  model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

  #ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
  #so the model or weights can be loaded later to continue the training from the state saved.
  checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

  #Stop training when a monitored metric has stopped improving.
  earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %%
# Train the model
epochs = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/20
# 282/282 [==============================] - ETA: 0s - loss: 1.7789 - accuracy: 0.3114
# Epoch 1: val_accuracy improved from -inf to 0.45087, saving model to model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 282/282 [==============================] - 1076s 760ms/step - loss: 1.7789 - accuracy: 0.3114 - val_loss: 1.4536 - val_accuracy: 0.4509
# Epoch 2/20
# 282/282 [==============================] - ETA: 0s - loss: 1.3708 - accuracy: 0.4695
# Epoch 2: val_accuracy improved from 0.45087 to 0.54913, saving model to model.h5
# 282/282 [==============================] - 16s 55ms/step - loss: 1.3708 - accuracy: 0.4695 - val_loss: 1.2151 - val_accuracy: 0.5491
# Epoch 3/20
# 282/282 [==============================] - ETA: 0s - loss: 1.2413 - accuracy: 0.5323
# Epoch 3: val_accuracy improved from 0.54913 to 0.57314, saving model to model.h5
# 282/282 [==============================] - 16s 55ms/step - loss: 1.2413 - accuracy: 0.5323 - val_loss: 1.1308 - val_accuracy: 0.5731
# Epoch 4/20
# 282/282 [==============================] - ETA: 0s - loss: 1.0546 - accuracy: 0.6032
# Epoch 4: val_accuracy improved from 0.57314 to 0.66919, saving model to model.h5
# 282/282 [==============================] - 16s 56ms/step - loss: 1.0546 - accuracy: 0.6032 - val_loss: 0.9003 - val_accuracy: 0.6692
# Epoch 5/20
# 282/282 [==============================] - ETA: 0s - loss: 0.9359 - accuracy: 0.6524
# Epoch 5: val_accuracy did not improve from 0.66919
# 282/282 [==============================] - 15s 55ms/step - loss: 0.9359 - accuracy: 0.6524 - val_loss: 0.9438 - val_accuracy: 0.6474
# Epoch 6/20
# 282/282 [==============================] - ETA: 0s - loss: 0.7910 - accuracy: 0.7023
# Epoch 6: val_accuracy improved from 0.66919 to 0.71365, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.7910 - accuracy: 0.7023 - val_loss: 0.7869 - val_accuracy: 0.7137
# Epoch 7/20
# 282/282 [==============================] - ETA: 0s - loss: 0.6978 - accuracy: 0.7394
# Epoch 7: val_accuracy improved from 0.71365 to 0.76656, saving model to model.h5
# 282/282 [==============================] - 16s 55ms/step - loss: 0.6978 - accuracy: 0.7394 - val_loss: 0.6238 - val_accuracy: 0.7666
# Epoch 8/20
# 282/282 [==============================] - ETA: 0s - loss: 0.6028 - accuracy: 0.7729
# Epoch 8: val_accuracy improved from 0.76656 to 0.81236, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.6028 - accuracy: 0.7729 - val_loss: 0.4873 - val_accuracy: 0.8124
# Epoch 9/20
# 282/282 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.7748
# Epoch 9: val_accuracy did not improve from 0.81236
# 282/282 [==============================] - 15s 54ms/step - loss: 0.6020 - accuracy: 0.7748 - val_loss: 0.5992 - val_accuracy: 0.7621
# Epoch 10/20
# 282/282 [==============================] - ETA: 0s - loss: 0.5067 - accuracy: 0.8156
# Epoch 10: val_accuracy improved from 0.81236 to 0.84571, saving model to model.h5
# 282/282 [==============================] - 16s 56ms/step - loss: 0.5067 - accuracy: 0.8156 - val_loss: 0.4547 - val_accuracy: 0.8457
# Epoch 11/20
# 282/282 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.8265
# Epoch 11: val_accuracy improved from 0.84571 to 0.85060, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.4662 - accuracy: 0.8265 - val_loss: 0.4416 - val_accuracy: 0.8506
# Epoch 12/20
# 282/282 [==============================] - ETA: 0s - loss: 0.4027 - accuracy: 0.8452
# Epoch 12: val_accuracy improved from 0.85060 to 0.86438, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.4027 - accuracy: 0.8452 - val_loss: 0.4077 - val_accuracy: 0.8644
# Epoch 13/20
# 281/282 [============================>.] - ETA: 0s - loss: 0.3945 - accuracy: 0.8521
# Epoch 13: val_accuracy did not improve from 0.86438
# 282/282 [==============================] - 15s 54ms/step - loss: 0.3958 - accuracy: 0.8516 - val_loss: 0.4430 - val_accuracy: 0.8426
# Epoch 14/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3767 - accuracy: 0.8582
# Epoch 14: val_accuracy improved from 0.86438 to 0.87683, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.3767 - accuracy: 0.8582 - val_loss: 0.3541 - val_accuracy: 0.8768
# Epoch 15/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.8591
# Epoch 15: val_accuracy improved from 0.87683 to 0.88084, saving model to model.h5
# 282/282 [==============================] - 15s 54ms/step - loss: 0.3688 - accuracy: 0.8591 - val_loss: 0.3609 - val_accuracy: 0.8808
# Epoch 16/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3453 - accuracy: 0.8676
# Epoch 16: val_accuracy did not improve from 0.88084
# 282/282 [==============================] - 15s 54ms/step - loss: 0.3453 - accuracy: 0.8676 - val_loss: 0.5701 - val_accuracy: 0.8088
# Epoch 17/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3323 - accuracy: 0.8723
# Epoch 17: val_accuracy improved from 0.88084 to 0.88528, saving model to model.h5
# 282/282 [==============================] - 15s 54ms/step - loss: 0.3323 - accuracy: 0.8723 - val_loss: 0.3356 - val_accuracy: 0.8853
# Epoch 18/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3280 - accuracy: 0.8734
# Epoch 18: val_accuracy improved from 0.88528 to 0.89818, saving model to model.h5
# 282/282 [==============================] - 16s 55ms/step - loss: 0.3280 - accuracy: 0.8734 - val_loss: 0.3160 - val_accuracy: 0.8982
# Epoch 19/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3210 - accuracy: 0.8730
# Epoch 19: val_accuracy did not improve from 0.89818
# 282/282 [==============================] - 15s 53ms/step - loss: 0.3210 - accuracy: 0.8730 - val_loss: 0.4066 - val_accuracy: 0.8675
# Epoch 20/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.8863
# Epoch 20: val_accuracy did not improve from 0.89818
# 282/282 [==============================] - 15s 53ms/step - loss: 0.3064 - accuracy: 0.8863 - val_loss: 0.3169 - val_accuracy: 0.8928

# %%
def plotTrainingCurve():
  # Plot the training curves
  epochs_range = range(earlystop.stopped_epoch+1)

  plt.figure(figsize=(15, 10))
  plt.subplot(1, 2, 1)

  #Plot Model Accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel(epochs_range)
  plt.legend(['train', 'val'], loc='upper left')

  #Plot Model Loss
  plt.subplot(1, 2, 2)
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel(epochs_range)
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

plotTrainingCurve()

# %% [markdown]
# **Model Prediction**

# %%
def predictModel():
  from glob import glob
  Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
  Test_image = glob(Test_image_path)
  Test_image = load_img(Test_image[-1],target_size=(180,180,3))
  plt.imshow(Test_image)
  plt.grid(False)

  img = np.expand_dims(Test_image,axis=0)
  pred = model.predict(img)
  pred = np.argmax(pred)
  pred_class = class_names[pred]
  print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )

predictModel()
# Out:
# 1/1 [==============================] - 0s 358ms/step
# Actual Class basal cell carcinoma
# Predictive Class squamous cell carcinoma

# %% [markdown]
# **Data augmentation	**

# %%
#install Augmentor
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %%
path_to_training_dataset="/content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)  #Adding 500 samples per class to make sure that none of the classes are sparse
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F89A87BBBE0>: 100%|██████████| 500/500 [00:25<00:00, 19.55 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F89A8607DC0>: 100%|██████████| 500/500 [00:24<00:00, 20.26 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F89AC817C10>: 100%|██████████| 500/500 [00:20<00:00, 24.37 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F89ACD003D0>: 100%|██████████| 500/500 [01:39<00:00,  5.04 Samples/s]
# Initialised with 365 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F89ACD00C70>: 100%|██████████| 500/500 [01:28<00:00,  5.66 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F89A8602140>: 100%|██████████| 500/500 [00:18<00:00, 26.34 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F89AC869360>: 100%|██████████| 500/500 [00:43<00:00, 11.47 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F89ACD54790>: 100%|██████████| 500/500 [00:18<00:00, 26.49 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Others/CNN_Assignment/Melanoma/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F89ACFA3550>: 100%|██████████| 500/500 [00:19<00:00, 26.18 Samples/s]

# %%
#Count total number of image generated by Augmentor.
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 13500

# %%
model = BuildModel()
model
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 89, 89, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 128)               6553728
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6648137 (25.36 MB)
# Trainable params: 6648137 (25.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Compile the Model
#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %%
# Train the model
epochs = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/20
# 282/282 [==============================] - ETA: 0s - loss: 1.6869 - accuracy: 0.3429
# Epoch 1: val_accuracy improved from -inf to 0.43486, saving model to model.h5
# 282/282 [==============================] - 18s 59ms/step - loss: 1.6869 - accuracy: 0.3429 - val_loss: 1.4369 - val_accuracy: 0.4349
# Epoch 2/20
# 282/282 [==============================] - ETA: 0s - loss: 1.3428 - accuracy: 0.4813
# Epoch 2: val_accuracy improved from 0.43486 to 0.53357, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 1.3428 - accuracy: 0.4813 - val_loss: 1.1778 - val_accuracy: 0.5336
# Epoch 3/20
# 282/282 [==============================] - ETA: 0s - loss: 1.1894 - accuracy: 0.5488
# Epoch 3: val_accuracy improved from 0.53357 to 0.59404, saving model to model.h5
# 282/282 [==============================] - 16s 55ms/step - loss: 1.1894 - accuracy: 0.5488 - val_loss: 1.1258 - val_accuracy: 0.5940
# Epoch 4/20
# 282/282 [==============================] - ETA: 0s - loss: 1.0369 - accuracy: 0.6107
# Epoch 4: val_accuracy did not improve from 0.59404
# 282/282 [==============================] - 15s 54ms/step - loss: 1.0369 - accuracy: 0.6107 - val_loss: 1.0786 - val_accuracy: 0.5927
# Epoch 5/20
# 282/282 [==============================] - ETA: 0s - loss: 0.8807 - accuracy: 0.6694
# Epoch 5: val_accuracy improved from 0.59404 to 0.70965, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.8807 - accuracy: 0.6694 - val_loss: 0.8050 - val_accuracy: 0.7096
# Epoch 6/20
# 282/282 [==============================] - ETA: 0s - loss: 0.7564 - accuracy: 0.7194
# Epoch 6: val_accuracy improved from 0.70965 to 0.74566, saving model to model.h5
# 282/282 [==============================] - 16s 56ms/step - loss: 0.7564 - accuracy: 0.7194 - val_loss: 0.7139 - val_accuracy: 0.7457
# Epoch 7/20
# 282/282 [==============================] - ETA: 0s - loss: 0.6808 - accuracy: 0.7516
# Epoch 7: val_accuracy improved from 0.74566 to 0.77279, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.6808 - accuracy: 0.7516 - val_loss: 0.6332 - val_accuracy: 0.7728
# Epoch 8/20
# 282/282 [==============================] - ETA: 0s - loss: 0.5875 - accuracy: 0.7800
# Epoch 8: val_accuracy improved from 0.77279 to 0.82392, saving model to model.h5
# 282/282 [==============================] - 16s 58ms/step - loss: 0.5875 - accuracy: 0.7800 - val_loss: 0.4884 - val_accuracy: 0.8239
# Epoch 9/20
# 281/282 [============================>.] - ETA: 0s - loss: 0.5079 - accuracy: 0.8081
# Epoch 9: val_accuracy did not improve from 0.82392
# 282/282 [==============================] - 15s 55ms/step - loss: 0.5079 - accuracy: 0.8078 - val_loss: 0.4991 - val_accuracy: 0.8084
# Epoch 10/20
# 282/282 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.8254
# Epoch 10: val_accuracy improved from 0.82392 to 0.83815, saving model to model.h5
# 282/282 [==============================] - 16s 55ms/step - loss: 0.4663 - accuracy: 0.8254 - val_loss: 0.4392 - val_accuracy: 0.8382
# Epoch 11/20
# 281/282 [============================>.] - ETA: 0s - loss: 0.4181 - accuracy: 0.8460
# Epoch 11: val_accuracy did not improve from 0.83815
# 282/282 [==============================] - 17s 59ms/step - loss: 0.4191 - accuracy: 0.8461 - val_loss: 0.5410 - val_accuracy: 0.8119
# Epoch 12/20
# 282/282 [==============================] - ETA: 0s - loss: 0.4189 - accuracy: 0.8405
# Epoch 12: val_accuracy improved from 0.83815 to 0.87639, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.4189 - accuracy: 0.8405 - val_loss: 0.3684 - val_accuracy: 0.8764
# Epoch 13/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3546 - accuracy: 0.8625
# Epoch 13: val_accuracy did not improve from 0.87639
# 282/282 [==============================] - 15s 54ms/step - loss: 0.3546 - accuracy: 0.8625 - val_loss: 0.3818 - val_accuracy: 0.8662
# Epoch 14/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3626 - accuracy: 0.8613
# Epoch 14: val_accuracy did not improve from 0.87639
# 282/282 [==============================] - 15s 54ms/step - loss: 0.3626 - accuracy: 0.8613 - val_loss: 0.3469 - val_accuracy: 0.8719
# Epoch 15/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3531 - accuracy: 0.8652
# Epoch 15: val_accuracy improved from 0.87639 to 0.88039, saving model to model.h5
# 282/282 [==============================] - 16s 55ms/step - loss: 0.3531 - accuracy: 0.8652 - val_loss: 0.3541 - val_accuracy: 0.8804
# Epoch 16/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3015 - accuracy: 0.8872
# Epoch 16: val_accuracy improved from 0.88039 to 0.89951, saving model to model.h5
# 282/282 [==============================] - 15s 55ms/step - loss: 0.3015 - accuracy: 0.8872 - val_loss: 0.3265 - val_accuracy: 0.8995
# Epoch 17/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.8859
# Epoch 17: val_accuracy did not improve from 0.89951
# 282/282 [==============================] - 16s 56ms/step - loss: 0.3020 - accuracy: 0.8859 - val_loss: 0.3315 - val_accuracy: 0.8764
# Epoch 18/20
# 282/282 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8792
# Epoch 18: val_accuracy did not improve from 0.89951
# 282/282 [==============================] - 16s 56ms/step - loss: 0.3232 - accuracy: 0.8792 - val_loss: 0.3465 - val_accuracy: 0.8853
# Epoch 19/20
# 282/282 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.8974
# Epoch 19: val_accuracy did not improve from 0.89951
# 282/282 [==============================] - 16s 56ms/step - loss: 0.2634 - accuracy: 0.8974 - val_loss: 0.3359 - val_accuracy: 0.8893
# Epoch 20/20
# 282/282 [==============================] - ETA: 0s - loss: 0.2631 - accuracy: 0.8993
# Epoch 20: val_accuracy did not improve from 0.89951
# 282/282 [==============================] - 16s 56ms/step - loss: 0.2631 - accuracy: 0.8993 - val_loss: 0.3224 - val_accuracy: 0.8933

# %%
def plotTrainingCurve():
  # Plot the training curves
  epochs_range = range(earlystop.stopped_epoch+1)

  plt.figure(figsize=(15, 10))
  plt.subplot(1, 2, 1)

  #Plot Model Accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel(epochs_range)
  plt.legend(['train', 'val'], loc='upper left')

  #Plot Model Loss
  plt.subplot(1, 2, 2)
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel(epochs_range)
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

plotTrainingCurve()

# %% [markdown]
# **Model Prediction**

# %%
def predictModel():
  from glob import glob
  Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
  Test_image = glob(Test_image_path)
  Test_image = load_img(Test_image[-1],target_size=(180,180,3))
  plt.imshow(Test_image)
  plt.grid(False)

  img = np.expand_dims(Test_image,axis=0)
  pred = model.predict(img)
  pred = np.argmax(pred)
  pred_class = class_names[pred]
  print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )

predictModel()
# Out:
# 1/1 [==============================] - 0s 75ms/step
# Actual Class basal cell carcinoma
# Predictive Class squamous cell carcinoma
